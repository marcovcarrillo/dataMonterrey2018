# %% [markdown]
# ### CARRILLO TRUJILLO MARCO VINICIO

# %% [markdown]
# ### YASACA PUCUNA SAUL

# %% [markdown]
# Datos: https://portal.monterrey.gob.mx/transparencia/Oficial/Index_Proveedores_Contratistas.asp

# %% [markdown]
# ## PAGOS A PROVEEDORES Y CONTRATISTAS, GOBIERNO DE MONTERREY 2018

# %%
# %matplotlib inline
import pandas as pd

# %%
compras_df = pd.read_csv('clean_compras_2018.csv')

# %%
ls
# Out:
#  El volumen de la unidad C es Windows
#  El número de serie del volumen es: 26DF-D79C
#
#  Directorio de C:\Users\WINDOWS\Documents\INTELIGENCIA ARTIFICIAL\PROYECTO
#
# 19/10/2024  10:39    <DIR>          .
# 17/10/2024  19:19    <DIR>          ..
# 19/10/2024  10:17    <DIR>          .ipynb_checkpoints
# 18/10/2024  00:14            31.678 1. ENERO 2018.xlsx
# 19/10/2024  10:39            78.237 1. LIMPIEZA.ipynb
# 18/10/2024  00:14           376.719 10. OCTUBRE 2018.xlsx
# 18/10/2024  00:14            64.087 11. NOVIEMBRE 2018.xlsx
# 18/10/2024  00:14           154.729 12. DICIEMBRE 2018.xlsx
# 19/10/2024  10:39           431.624 2. ANALISIS.ipynb
# 18/10/2024  00:14            68.990 2. FEBRERO 2018.xlsx
# 19/10/2024  10:19            19.095 3. ENRIQUCIMIENTO.ipynb
# 18/10/2024  00:14           162.700 3. MARZO 2018.xlsx
# 18/10/2024  00:14           120.864 4. ABRIL 2018.xlsx
# 19/10/2024  10:19            37.474 4_MODELADO.ipynb
# ...

# %%
compras_df.head(4)
# Out:
#    PROVINCIA                      BENEFICIARIO            RFC  \
# 0     113596          GONZALEZ GARZA ROSA LILA  GOGR630616KP2
# 1     114085  BUFETE URBANISTICO, S.A. DE C.V.   BUR001114GL6
# 2     114085  BUFETE URBANISTICO, S.A. DE C.V.   BUR001114GL6
# 3     114196     CLIMEEZ DEL NORTE,S.A.DE C.V.   CNO8005284F6
#
#               FACTURA      CONTRATO  \
# 0   3624-158003-11778  SPP-318-2018
# 1     189-155002-2519  SOP-802-2017
# 2     191-155002-2532  SOP-807-2017
# 3  FF384-158003-11871  DIF-039-2018
#
#                                             CONCEPTO TIPO OP       FDO OP  \
# 0  ADQUISICION DE UNIFORMES PARA EL PERSONAL OPER...      TR  262000010.0
# 1  R33-2017 EST. 4 (TECHOS) OP-R33-01/17-IR CONST...      TR  243000132.0
# 2  R23-2017  (PROREG) EST. 7 OP-R23(PROREG)-06/17...      TR  249000105.0
# 3  SUMINISTRO E INSTALACION DE MOBILIARIO Y EQUIP...      TR  260000019.0
#
#         FECHA    IMPORTE      ETIQUETA
# 0  2018-12-20  233956.92  CONTRATISTAS
# ...

# %%
compras_df.dtypes
# Out:
# PROVINCIA         int64
# BENEFICIARIO     object
# RFC              object
# FACTURA          object
# CONTRATO         object
# CONCEPTO         object
# TIPO OP          object
# FDO OP          float64
# FECHA            object
# IMPORTE         float64
# ETIQUETA         object
# dtype: object

# %%
compras_df['FECHA']=pd.to_datetime(compras_df['FECHA'])

# %%
compras_df['DIA']=compras_df['FECHA'].apply(lambda x: x.day)

# %%
compras_df['MES']=compras_df['FECHA'].apply(lambda x: x.month)

# %%
compras_df['ANIO']=compras_df['FECHA'].apply(lambda x: x.year)

# %%
compras_df.dtypes
# Out:
# PROVINCIA                int64
# BENEFICIARIO            object
# RFC                     object
# FACTURA                 object
# CONTRATO                object
# CONCEPTO                object
# TIPO OP                 object
# FDO OP                 float64
# FECHA           datetime64[ns]
# IMPORTE                float64
# ETIQUETA                object
# DIA                      int64
# MES                      int64
# ANIO                     int64
# dtype: object

# %%
compras_df.head(5)
# Out:
#    PROVINCIA                              BENEFICIARIO            RFC  \
# 0     113596                  GONZALEZ GARZA ROSA LILA  GOGR630616KP2
# 1     114085          BUFETE URBANISTICO, S.A. DE C.V.   BUR001114GL6
# 2     114085          BUFETE URBANISTICO, S.A. DE C.V.   BUR001114GL6
# 3     114196             CLIMEEZ DEL NORTE,S.A.DE C.V.   CNO8005284F6
# 4     114214  TOOLS & SERVICES DE MEXICO, S.A. DE C.V.  T&S000219-JE7
#
#               FACTURA      CONTRATO  \
# 0   3624-158003-11778  SPP-318-2018
# 1     189-155002-2519  SOP-802-2017
# 2     191-155002-2532  SOP-807-2017
# 3  FF384-158003-11871  DIF-039-2018
# 4  P9696-158003-12267  SPP-317-2018
#
#                                             CONCEPTO TIPO OP       FDO OP  \
# 0  ADQUISICION DE UNIFORMES PARA EL PERSONAL OPER...      TR  262000010.0
# 1  R33-2017 EST. 4 (TECHOS) OP-R33-01/17-IR CONST...      TR  243000132.0
# 2  R23-2017  (PROREG) EST. 7 OP-R23(PROREG)-06/17...      TR  249000105.0
# ...

# %% [markdown]
# ## Proyectar una variable con otra

# %%
beneficiario_sales=compras_df['BENEFICIARIO'].value_counts().to_dict()

# %%
list(beneficiario_sales.keys())[0:5]
# Out:
# ['CAR ONE MONTERREY, S.A. DE C.V.',
#  'CAMARA MEXICANA DE LA INDUSTRIA DE LA CONSTRUCCION',
#  'DISTRIBUIDORA DE FRUTAS Y LEGUMBRES LA HORTALIZA,S.A.DE C.V.',
#  'INTERASFALTOS, S.A. DE C.V.',
#  'SECRETARIA DE FINANZAS Y TESORERIA GRAL DEL EDO DE NL']

# %%
compras_df['BENEFICIARIO_SALES']=compras_df['BENEFICIARIO'].apply(lambda x: beneficiario_sales[x])

# %%
compras_df.head(4)
# Out:
#    PROVINCIA                      BENEFICIARIO            RFC  \
# 0     113596          GONZALEZ GARZA ROSA LILA  GOGR630616KP2
# 1     114085  BUFETE URBANISTICO, S.A. DE C.V.   BUR001114GL6
# 2     114085  BUFETE URBANISTICO, S.A. DE C.V.   BUR001114GL6
# 3     114196     CLIMEEZ DEL NORTE,S.A.DE C.V.   CNO8005284F6
#
#               FACTURA      CONTRATO  \
# 0   3624-158003-11778  SPP-318-2018
# 1     189-155002-2519  SOP-802-2017
# 2     191-155002-2532  SOP-807-2017
# 3  FF384-158003-11871  DIF-039-2018
#
#                                             CONCEPTO TIPO OP       FDO OP  \
# 0  ADQUISICION DE UNIFORMES PARA EL PERSONAL OPER...      TR  262000010.0
# 1  R33-2017 EST. 4 (TECHOS) OP-R33-01/17-IR CONST...      TR  243000132.0
# 2  R23-2017  (PROREG) EST. 7 OP-R23(PROREG)-06/17...      TR  249000105.0
# 3  SUMINISTRO E INSTALACION DE MOBILIARIO Y EQUIP...      TR  260000019.0
#
#        FECHA    IMPORTE      ETIQUETA  DIA  MES  ANIO  BENEFICIARIO_SALES
# ...

# %%
sheet_mean_compras=compras_df.groupby('ETIQUETA')['IMPORTE'].mean()

# %%
sheet_mean_compras
# Out:
# ETIQUETA
# COMUNICACIÓN                76361.545054
# CONTRATISTAS               572437.711754
# REPRESENTANTE               14050.376827
# SERVICIOS PERSONALES        32307.708799
# SERVICIOS PROFESIONALES    377515.937596
# VARIOS                     358456.287522
# Name: IMPORTE, dtype: float64

# %%
sheet_mean_compras.to_dict()
# Out:
# {'COMUNICACIÓN': 76361.54505422994,
#  'CONTRATISTAS': 572437.7117536814,
#  'REPRESENTANTE': 14050.376826923077,
#  'SERVICIOS PERSONALES': 32307.70879944483,
#  'SERVICIOS PROFESIONALES': 377515.93759581883,
#  'VARIOS': 358456.2875216559}

# %%
compras_df['IMPORTE_GASTO_PROMEDIO']=compras_df['ETIQUETA'].apply(lambda x: sheet_mean_compras[x])

# %%
compras_df.to_csv(r'C:\Users\WINDOWS\Documents\INTELIGENCIA ARTIFICIAL\PROYECTO\compras_df_enriched.csv', index=None)

# %%
compras_df.head(10)
# Out:
#    PROVINCIA                              BENEFICIARIO            RFC  \
# 0     113596                  GONZALEZ GARZA ROSA LILA  GOGR630616KP2
# 1     114085          BUFETE URBANISTICO, S.A. DE C.V.   BUR001114GL6
# 2     114085          BUFETE URBANISTICO, S.A. DE C.V.   BUR001114GL6
# 3     114196             CLIMEEZ DEL NORTE,S.A.DE C.V.   CNO8005284F6
# 4     114214  TOOLS & SERVICES DE MEXICO, S.A. DE C.V.  T&S000219-JE7
# 5     114542  INTER @ ENTER COMPUTADORAS, S.A. DE C.V.   IAE060118A50
# 6     114913          FORTE COMUNICACIONES,S.A.DE C.V.   FCO970603C36
# 7     115066               RANGEL BANDA JANNET EUGENIA  RABJ790521D26
# 8     115066               RANGEL BANDA JANNET EUGENIA  RABJ790521D26
# 9     116429                   VALERE CONSULTORES, S.C   VCO1112138L9
#
#                 FACTURA              CONTRATO  \
# 0     3624-158003-11778          SPP-318-2018
# 1       189-155002-2519          SOP-802-2017
# 2       191-155002-2532          SOP-807-2017
# ...
